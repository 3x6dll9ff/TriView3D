# %% [markdown]
# # Обучение Generative VAE модели
#
# Этот ноутбук предназначен для запуска на **Google Colab (с GPU T4)**.

# %%
# 1. Монтируем Google Drive (чтобы взять оттуда данные и сохранить туда модель)
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Скачиваем актуальный код с GitHub
# !git clone https://github.com/3x6dll9ff/MultiView_3D_Prediction.git
# %cd MultiView_3D_Prediction

# %%
# 3. Устанавливаем зависимости
# !pip install -r requirements.txt

# %%
# 4. Распаковываем подготовленные данные с твоего Google Drive
# УБЕДИСЬ, что ты загрузил файл data_processed.zip в корень Google Drive
# !unzip -q /content/drive/MyDrive/data_processed.zip -d .
# !ls data/processed

# %%
# 5. Запускаем обучение!
# !python3 src/train_vae.py --epochs 50 --batch_size 16

# %%
# 6. Копируем результат обучения обратно на Google Drive
# !cp -r results /content/drive/MyDrive/MultiView_Results
print("Модель успешно сохранена на Google Drive!")
